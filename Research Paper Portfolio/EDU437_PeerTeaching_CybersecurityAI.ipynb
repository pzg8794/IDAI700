# %% [markdown]
# # 🔐 Cybersecurity in Healthcare AI Networks
# **EDU437 Peer Teaching Module — Colab Notebook**
#
# Welcome! This interactive notebook guides you through core challenges in protecting patient data when AI is used in healthcare. You'll explore bias, privacy, equity, and mitigation through guided code, reflection, and design prompts.
#
# ---
#
# ⏳ **Estimated Time**: 30–40 minutes
# 🎯 **Skills**: Debugging, Ethical Reasoning, Systems Thinking, Bias Detection
# 📚 **Frameworks**: UDL • EQUITAS • Student-Centered Computing • Coding-as-Literacy

# %% [markdown]
# ## 💬 Pre-Lab Equity Prompt
# Think about this before we begin:
#
# > **What does “security” mean when you are the patient?**
# >
# > Whose privacy is prioritized — and whose isn’t?
#
# Write your thoughts below:

# %%
# Type your thoughts here

# %% [markdown]
# ## 🏥 Simulated Scenario: AI Diagnostic System Under Threat
#
# Imagine you're working in a clinic that uses an AI model to flag abnormal blood test results. Overnight, the system gets hit with a ransomware attack. Here's the dataset you're analyzing to find weaknesses.
#
# Let's simulate some diagnostics traffic and see where the vulnerabilities might lie:

# %%
import pandas as pd

# Simulated diagnostic traffic logs (for demo)
data = {
    'PatientID': ['P001', 'P002', 'P003', 'P004'],
    'Result': ['Normal', 'Abnormal', 'Abnormal', 'Normal'],
    'FlaggedByAI': [True, False, True, False],
    'Demographic': ['Low-income', 'Immigrant', 'Elderly', 'Low-income'],
    'DelayFromAttack(min)': [0, 45, 30, 0]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## ⚖️ Bias & Equity Checkpoint
#
# Who was flagged correctly? Who experienced delays? Are there patterns by group?
#
# Discuss with a partner or jot your thoughts below:

# %%
# Bias reflection area

# %% [markdown]
# ## 🔐 Threat Modeling: Preventing Harm
#
# Use the CIA Triad to assess one weak point in this AI system:
#
# - **C**onfidentiality: Was sensitive data exposed?
# - **I**ntegrity: Could the results be altered?
# - **A**vailability: Who was impacted by the outage?
#
# Choose one and suggest a fix:

# %%
# CIA fix ideas here

# %% [markdown]
# ## 🎯 Exit Ticket
#
# 1. One thing I learned about equity and AI security is...
# 2. One way I might apply this in my teaching is...
#
# _Type below or share aloud with your peer teacher._

# %%
# Exit reflections
